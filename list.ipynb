# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj6300/sueaj_305_/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [1, 2, 3, 4, 5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
nums = []
nums.append(10)
nums.append(20)
nums.append(30)
print(nums)
# Out:
# [10, 20, 30]

# %%
nums = [10, 20, 30]
nums.insert(1, 15)
print(nums)
# Out:
# [10, 15, 20, 30]
