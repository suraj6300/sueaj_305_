# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj6300/sueaj_305_/blob/main/dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {
    "name": "John",
    "age": 20,
    "course": "Python"
}
print(student)
# Out:
# {'name': 'John', 'age': 20, 'course': 'Python'}

# %%
student = {"name": "John", "age": 20}
print(student["name"])
print(student.get("age"))
# Out:
# John
# 20

# %%
student = {"name": "John", "age": 20}
student["marks"] = 85
print(student)
# Out:
# {'name': 'John', 'age': 20, 'marks': 85}
